# %% [markdown]
# 素数を求めます。ある数（整数Ａ）が２～Ａ／２までの数の各々で割り切れるかどうかを判定し、割り切れる場合があれば素数ではなく、一度も割り切れなければ素数、という計算を実行しています。計算回数は相当の数(約25万回）になります。もっとうまい方法があるカモとは思います。
# 計算回数と計算所要時間も計算しています。
# 24万9千回の計算が90秒で完了しています（所要時間は実行時によって異なるようだ）。中村用P（CPUCはi7)では2231秒と、20倍以上の時間を要しました。ここでの計算速度は使用する端末の性能にはよらず、Google Colabサーバーのコンピュータの性能（および使用状態）によるものです。
# 下の「コードセル（プログラムの書かれたブロック）」の先頭の{ }の上にカーソルを載せると▶が表示されるので、その▶をクリックすると、そのブロックのプログラムが実行される。プログラムのブロックが複数ある場合は、複数回実行する。
# 実行してみてください。
# ★★体験された方は、コメント/感想等頂ければ幸いです。★★
# 開始時間、終了時間を一般的な表記（日本標準時）に変更しました。
# 　<prog.viscuit@gmail.com>

# %%
import datetime
dt_now = datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=9)))


import time
t0 = time.time()
print("開始時間＝",t0)
kaisu = 0
num = 0
max = 1000
min = 4
for i in range(min,max):
    b = 0
    c = 0
    for k in range(2,(i//2+1)):
        kaisu = kaisu +1 
        print("i=",i,"k=",k)
        a = i % k
        if a == 0:
            b = b + 1
            print(i,"/",k,"が割切れ")
        else:
            c = c + 1
            # print("i=",i,"c=",c)
    if b > 0 :
        print("i=",i,"割切れ回数b=",b,"非素数")
    elif  c>0:
        print("i=",i,"割切れない回数c=",c,"素数")
        num = num + 1
    else:
        print("i=",i,"?")


print(min,"から",max,"までの素数の数は",num)
print("処理回数は",kaisu)
dt_end = datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=9)))
t1 = time.time()
tt = t1 - t0
ut = tt / kaisu
print("開始時間",dt_now)
print("終了時間",dt_end)
print("処理時間は",tt)
print("１回当たりの処理時間は",ut)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# i= 990 k= 28
# i= 990 k= 29
# i= 990 k= 30
# 990 / 30 が割切れ
# i= 990 k= 31
# i= 990 k= 32
# i= 990 k= 33
# 990 / 33 が割切れ
# i= 990 k= 34
# i= 990 k= 35
# i= 990 k= 36
# i= 990 k= 37
# i= 990 k= 38
# i= 990 k= 39
# i= 990 k= 40
# i= 990 k= 41
# i= 990 k= 42
# i= 990 k= 43
# i= 990 k= 44
# i= 990 k= 45
# 990 / 45 が割切れ
# i= 990 k= 46
# i= 990 k= 47
# i= 990 k= 48
# i= 990 k= 49
# i= 990 k= 50
# i= 990 k= 51
# i= 990 k= 52
# i= 990 k= 53
# i= 990 k= 54
# i= 990 k= 55
# 990 / 55 が割切れ
# i= 990 k= 56
# i= 990 k= 57
# i= 990 k= 58
# i= 990 k= 59
# i= 990 k= 60
# i= 990 k= 61
# i= 990 k= 62
# i= 990 k= 63
# i= 990 k= 64
# i= 990 k= 65
# i= 990 k= 66
# 990 / 66 が割切れ
# i= 990 k= 67
# i= 990 k= 68
# i= 990 k= 69
# i= 990 k= 70
# i= 990 k= 71
# i= 990 k= 72
# i= 990 k= 73
# i= 990 k= 74
# i= 990 k= 75
# i= 990 k= 76
# i= 990 k= 77
# i= 990 k= 78
# i= 990 k= 79
# i= 990 k= 80
# i= 990 k= 81
# i= 990 k= 82
# i= 990 k= 83
# i= 990 k= 84
# i= 990 k= 85
# i= 990 k= 86
# ...

# %%
import datetime
dt_now = datetime.datetime.now(datetime.timezone(datetime.timedelta(hours=9)))
print(dt_now)
# Out:
# 2020-12-11 22:46:38.833997+09:00
